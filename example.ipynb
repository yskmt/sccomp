# %%
run sccomp.py
# Out:
# dbs/gist_data.npy and dbs/file_names.npy already exist
# Choose the image number 0~2688
# 476
# Mask file already exist. Create a new one? (Y|n)
# n
#
# Images chosen from scene completion are:
# [ '/Users/ysakamoto/Projects/sccomp/data/scene_database/Opencountry/natu45.jpg'
#  '/Users/ysakamoto/Projects/sccomp/data/scene_database/forest/nat449.jpg'
#  '/Users/ysakamoto/Projects/sccomp/data/scene_database/forest/natu18.jpg'
#  '/Users/ysakamoto/Projects/sccomp/data/scene_database/forest/nat452.jpg'
#  '/Users/ysakamoto/Projects/sccomp/data/scene_database/forest/natu72.jpg']
#
# Original image with mask.
# Completed images from 1st to 5th choices:
