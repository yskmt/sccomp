# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
run sccomp.py
# Out:
# dbs/gist_data.npy and dbs/file_names.npy already exist
# Choose the image number 0~2688
# 987
# Mask file already exist. Create a new one? (Y|n)
# n
#
# Images chosen from scene completion are:
# [ '/Users/ysakamoto/Projects/sccomp/data/scene_database/inside_city/bost44.jpg'
#  '/Users/ysakamoto/Projects/sccomp/data/scene_database/inside_city/a379017.jpg'
#  '/Users/ysakamoto/Projects/sccomp/data/scene_database/inside_city/art1363.jpg'
#  '/Users/ysakamoto/Projects/sccomp/data/scene_database/inside_city/art638.jpg'
#  '/Users/ysakamoto/Projects/sccomp/data/scene_database/inside_city/art847.jpg']
#
# Original image with mask.
# Completed images from 1st to 5th choices:
